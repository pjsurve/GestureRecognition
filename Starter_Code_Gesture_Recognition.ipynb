# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started. Once you have completed the code you can download the notebook for making a submission.

# %%
import numpy as np
import os
from imageio import imread
from skimage.transform import resize
import datetime
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from tensorflow import keras
import tensorflow as tf
tf.random.set_seed(30)

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %% [markdown]
# **data path: /home/datasets/Project_data**

# %%
train_doc = np.random.permutation(open('/home/datasets/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('/home/datasets/Project_data/val.csv').readlines())
batch_size = 64
seq_idx = range(5,25,1)
dim_x, dim_y = 120, 120
print("Num of frames per video:", len(seq_idx))
# Out:
# Num of frames per video: 20

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
def generator(source_path, folder_list, batch_size, print_img = False, show_stat = False):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    img_idx = seq_idx
    x = len(img_idx)
    y, z = dim_x, dim_y
    while True:
        t = np.random.permutation(folder_list)
        if show_stat:
            print("#"*50)
            print("Length:", len(t))
            print("Batch size:", batch_size)
            print("Remaining videos:", len(t)%batch_size)
        if (len(t)%batch_size) == 0:
            num_batches = int(len(t)/batch_size)
        else:
            num_batches = len(t)//batch_size + 1
            batch_size = len(t)%batch_size
        if show_stat:
            print("No. of Batches:", num_batches)
            print("#"*50)
        for batch in range(num_batches): # we iterate over the number of batches
            batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                if print_img:
                    plt.figure(figsize=(20,5))
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    if print_img:
                        plt.subplot(2, x, idx+1)
                        plt.imshow(image.astype('uint8'))
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    if image.shape[1] > image.shape[0]:
                        diff_px = image.shape[1] - image.shape[0]
                    elif image.shape[0] > image.shape[1]:
                        diff_px = image.shape[0] - image.shape[1]
                    else:
                        diff_px = 0
                    crop_start = diff_px//2
                    crop_end = crop_start + image.shape[1]
                    image = image[:, crop_start:crop_end]
                    
                    resized_im = resize(image, (dim_x, dim_x))
                    
                    if print_img:
                        plt.subplot(2, x, idx+x+1)
                        plt.imshow(resized_im.astype('uint8'))
                    
                    batch_data[folder,idx,:,:,0] = resized_im[:,:,0]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,1] = resized_im[:,:,1]/255 #normalise and feed in the image
                    batch_data[folder,idx,:,:,2] = resized_im[:,:,2]/255 #normalise and feed in the image
                    
                    
                    
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
                print_img = False
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do

        
        # write the code for the remaining data points which are left after full batches

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = '/home/datasets/Project_data/train'
val_path = '/home/datasets/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 40
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 40

# %%
test_gen = generator(train_path, train_doc, batch_size, print_img = True, show_stat = True)
d = next(test_gen)[0]
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 64
# ##################################################
# Length: 663
# Batch size: 64
# Remaining videos: 23
# No. of Batches: 11
# ##################################################

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout, Flatten, BatchNormalization, Activation, Conv3D, MaxPooling3D, TimeDistributed, LSTM, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import optimizers

input_shape = (len(seq_idx), dim_x, dim_y, 3)
input_shape
# Out:
# (20, 120, 120, 3)

# %%
#1
#model = Sequential()
#model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape))
#model.add(MaxPooling3D(pool_size=2))

#model.add(Conv3D(64, kernel_size=3, activation='relu'))
#model.add(MaxPooling3D(pool_size=2))

#model.add(Flatten())
#model.add(Dense(256, activation='relu'))
#model.add(Dense(5, activation='softmax'))

# %%
#2
#model = Sequential()
##Layer1
#model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape, padding="same"))
#model.add(BatchNormalization())
#model.add(MaxPooling3D(pool_size=2))
#model.add(Dropout(0.5))
##Layer2
#model.add(Conv3D(64, kernel_size=3, activation='relu', padding="same"))
#model.add(BatchNormalization())
#model.add(Dropout(0.5))
##Layer3
#model.add(Conv3D(64, kernel_size=3, activation='relu'))
#model.add(BatchNormalization())
#model.add(MaxPooling3D(pool_size=2))
#model.add(Dropout(0.5))

#model.add(Flatten())
#model.add(Dense(256, activation='relu'))
#model.add(Dense(5, activation='softmax'))

# %%
#3, 4 and 5
#model = Sequential()
##Layer1
#model.add(Conv3D(32, kernel_size=3, activation='relu', input_shape=input_shape, padding="same"))
#model.add(BatchNormalization())
#model.add(MaxPooling3D(pool_size=2))
#model.add(Dropout(0.5))
#Layer2
#model.add(Conv3D(32, kernel_size=3, activation='relu', padding="same"))
#model.add(BatchNormalization())
#model.add(Dropout(0.5))
#Layer3
#model.add(Conv3D(64, kernel_size=3, activation='relu'))
#model.add(BatchNormalization())
#model.add(MaxPooling3D(pool_size=2))
#model.add(Dropout(0.5))

#model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.25))
#model.add(Flatten())
#model.add(Dense(5, activation='softmax'))

# %%
##6
#model = Sequential()
##Layer1
#model.add(TimeDistributed(Conv2D(32, kernel_size=3, activation='relu', padding="same"), input_shape=input_shape))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#model.add(Dropout(0.5))
##Layer2
#model.add(TimeDistributed(Conv2D(32, kernel_size=3, activation='relu', padding="same")))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(Dropout(0.5))
##Layer3
#model.add(TimeDistributed(Conv2D(64, kernel_size=3, activation='relu')))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#model.add(Dropout(0.5))

#model.add(TimeDistributed(Flatten()))
#model.add(LSTM(256))
#model.add(Dropout(0.25))
#
#model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.25))
#
#model.add(Dense(5, activation='softmax'))

# %%
##7
#model = Sequential()
##Layer1
#model.add(TimeDistributed(Conv2D(32, kernel_size=3, activation='relu', padding="same"), input_shape=input_shape))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#
##Layer2
#model.add(TimeDistributed(Conv2D(64, kernel_size=3, activation='relu', padding="same")))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#
##Layer3
#model.add(TimeDistributed(Conv2D(128, kernel_size=3, activation='relu', padding="same")))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#
##Layer4
#model.add(TimeDistributed(Conv2D(256, kernel_size=3, activation='relu', padding="same")))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#
#model.add(TimeDistributed(Flatten()))
#model.add(LSTM(256))
#model.add(Dropout(0.25))
#
#model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.25))
#model.add(Dense(5, activation='softmax'))

# %%
##8
#model = Sequential()
##Layer1
#model.add(TimeDistributed(Conv2D(16, kernel_size=3, activation='relu', padding="same"), input_shape=input_shape))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#
##Layer2
#model.add(TimeDistributed(Conv2D(32, kernel_size=3, activation='relu', padding="same")))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#
##Layer3
#model.add(TimeDistributed(Conv2D(64, kernel_size=3, activation='relu', padding="same")))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#
##Layer4
#model.add(TimeDistributed(Conv2D(128, kernel_size=3, activation='relu', padding="same")))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#
##Layer5
#model.add(TimeDistributed(Conv2D(256, kernel_size=3, activation='relu', padding="same")))
#model.add(TimeDistributed(BatchNormalization()))
#model.add(TimeDistributed(MaxPooling2D(pool_size=2)))
#
#model.add(TimeDistributed(Flatten()))
#model.add(LSTM(256))
#model.add(Dropout(0.25))
#
#model.add(Dense(256, activation='relu'))
#model.add(Dropout(0.25))
#model.add(Dense(5, activation='softmax'))

# %%
#9
model = Sequential()
#Layer1
model.add(Conv3D(16, kernel_size=3, activation='relu', padding="same", input_shape=input_shape))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=2))

#Layer2
model.add(Conv3D(32, kernel_size=3, activation='relu', padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=2))

#Layer3
model.add(Conv3D(64, kernel_size=3, activation='relu', padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=2))

#Layer4
model.add(Conv3D(128, kernel_size=3, activation='relu', padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=2))

#Layer5
model.add(Conv3D(256, kernel_size=3, activation='relu', padding="same"))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=2, padding='same'))

model.add(Flatten())
model.add(Dropout(0.25))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(5, activation='softmax'))
# Out:
# 2022-11-13 19:30:53.244873: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-11-13 19:30:53.244947: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22852 MB memory:  -> device: 0, name: Quadro RTX 6000, pci bus id: 0000:1b:00.0, compute capability: 7.5

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
optimiser = optimizers.Adam(lr=0.001)
model.build(input_shape)
model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print (model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 20, 120, 120, 16)  1312
#
#  batch_normalization (BatchN  (None, 20, 120, 120, 16)  64
#  ormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 10, 60, 60, 16)   0
#  )
#
#  conv3d_1 (Conv3D)           (None, 10, 60, 60, 32)    13856
#
#  batch_normalization_1 (Batc  (None, 10, 60, 60, 32)   128
#  hNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 5, 30, 30, 32)    0
#  3D)
#
#  conv3d_2 (Conv3D)           (None, 5, 30, 30, 64)     55360
#
#  batch_normalization_2 (Batc  (None, 5, 30, 30, 64)    256
#  hNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 2, 15, 15, 64)    0
#  3D)
#
#  conv3d_3 (Conv3D)           (None, 2, 15, 15, 128)    221312
#
#  batch_normalization_3 (Batc  (None, 2, 15, 15, 128)   512
#  hNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 1, 7, 7, 128)     0
#  3D)
#
#  conv3d_4 (Conv3D)           (None, 1, 7, 7, 256)      884992
#
#  batch_normalization_4 (Batc  (None, 1, 7, 7, 256)     1024
#  hNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 1, 4, 4, 256)     0
#  3D)
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense (Dense)               (None, 256)               1048832
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 2,228,933
# Trainable params: 2,227,941
# Non-trainable params: 992
# _________________________________________________________________
# None
# /usr/local/lib/python3.8/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = generator(train_path, train_doc, batch_size)
val_generator = generator(val_path, val_doc, batch_size)

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto',save_freq = "epoch")

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001, verbose=1)

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)

callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit` method to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %%
history = model.fit(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                    callbacks=callbacks_list, validation_data=val_generator, 
                    validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Source path =  /home/datasets/Project_data/train ; batch size = 64
# Epoch 1/40
# 2022-11-13 19:30:58.010373: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 11/11 [==============================] - ETA: 0s - loss: 3.5978 - categorical_accuracy: 0.3874Source path =  /home/datasets/Project_data/val ; batch size = 64
#
# Epoch 00001: saving model to model_init_2022-11-1319_30_47.423460/model-00001-3.59776-0.38735-1.65845-0.22222.h5
# 11/11 [==============================] - 48s 4s/step - loss: 3.5978 - categorical_accuracy: 0.3874 - val_loss: 1.6585 - val_categorical_accuracy: 0.2222 - lr: 0.0010
# Epoch 2/40
# 11/11 [==============================] - ETA: 0s - loss: 1.4444 - categorical_accuracy: 0.4928
# Epoch 00002: saving model to model_init_2022-11-1319_30_47.423460/model-00002-1.44441-0.49282-2.83815-0.25000.h5
# 11/11 [==============================] - 38s 4s/step - loss: 1.4444 - categorical_accuracy: 0.4928 - val_loss: 2.8382 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 3/40
# 11/11 [==============================] - ETA: 0s - loss: 1.4129 - categorical_accuracy: 0.5263
# Epoch 00003: saving model to model_init_2022-11-1319_30_47.423460/model-00003-1.41288-0.52632-5.58237-0.15625.h5
# 11/11 [==============================] - 33s 3s/step - loss: 1.4129 - categorical_accuracy: 0.5263 - val_loss: 5.5824 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 4/40
# 11/11 [==============================] - ETA: 0s - loss: 1.0790 - categorical_accuracy: 0.5672
# Epoch 00004: saving model to model_init_2022-11-1319_30_47.423460/model-00004-1.07899-0.56716-4.75724-0.12500.h5
# 11/11 [==============================] - 26s 3s/step - loss: 1.0790 - categorical_accuracy: 0.5672 - val_loss: 4.7572 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 5/40
# 11/11 [==============================] - ETA: 0s - loss: 0.7819 - categorical_accuracy: 0.6631
# Epoch 00005: saving model to model_init_2022-11-1319_30_47.423460/model-00005-0.78186-0.66310-7.34789-0.37500.h5
# 11/11 [==============================] - 24s 2s/step - loss: 0.7819 - categorical_accuracy: 0.6631 - val_loss: 7.3479 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 6/40
# 11/11 [==============================] - ETA: 0s - loss: 1.2087 - categorical_accuracy: 0.6257
# Epoch 00006: saving model to model_init_2022-11-1319_30_47.423460/model-00006-1.20870-0.62567-5.96524-0.37500.h5
# 11/11 [==============================] - 26s 2s/step - loss: 1.2087 - categorical_accuracy: 0.6257 - val_loss: 5.9652 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 7/40
# 11/11 [==============================] - ETA: 0s - loss: 0.9486 - categorical_accuracy: 0.6684
# Epoch 00007: saving model to model_init_2022-11-1319_30_47.423460/model-00007-0.94860-0.66845-8.57481-0.37500.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.9486 - categorical_accuracy: 0.6684 - val_loss: 8.5748 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 8/40
# 11/11 [==============================] - ETA: 0s - loss: 0.7027 - categorical_accuracy: 0.7219
# Epoch 00008: saving model to model_init_2022-11-1319_30_47.423460/model-00008-0.70274-0.72193-14.37412-0.00000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.7027 - categorical_accuracy: 0.7219 - val_loss: 14.3741 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 9/40
# 11/11 [==============================] - ETA: 0s - loss: 0.6596 - categorical_accuracy: 0.7754
# Epoch 00009: saving model to model_init_2022-11-1319_30_47.423460/model-00009-0.65959-0.77540-17.11160-0.12500.h5
# 11/11 [==============================] - 25s 3s/step - loss: 0.6596 - categorical_accuracy: 0.7754 - val_loss: 17.1116 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 10/40
# 11/11 [==============================] - ETA: 0s - loss: 0.6284 - categorical_accuracy: 0.7380
# Epoch 00010: saving model to model_init_2022-11-1319_30_47.423460/model-00010-0.62839-0.73797-12.93481-0.12500.h5
# 11/11 [==============================] - 24s 2s/step - loss: 0.6284 - categorical_accuracy: 0.7380 - val_loss: 12.9348 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 11/40
# 11/11 [==============================] - ETA: 0s - loss: 0.6578 - categorical_accuracy: 0.7326
# Epoch 00011: saving model to model_init_2022-11-1319_30_47.423460/model-00011-0.65776-0.73262-8.49584-0.37500.h5
# 11/11 [==============================] - 24s 2s/step - loss: 0.6578 - categorical_accuracy: 0.7326 - val_loss: 8.4958 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 12/40
# 11/11 [==============================] - ETA: 0s - loss: 0.6867 - categorical_accuracy: 0.7166
# Epoch 00012: saving model to model_init_2022-11-1319_30_47.423460/model-00012-0.68668-0.71658-14.91793-0.12500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.6867 - categorical_accuracy: 0.7166 - val_loss: 14.9179 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 13/40
# 11/11 [==============================] - ETA: 0s - loss: 0.5978 - categorical_accuracy: 0.7861
# Epoch 00013: saving model to model_init_2022-11-1319_30_47.423460/model-00013-0.59778-0.78610-11.03136-0.25000.h5
# 11/11 [==============================] - 24s 2s/step - loss: 0.5978 - categorical_accuracy: 0.7861 - val_loss: 11.0314 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 14/40
# 11/11 [==============================] - ETA: 0s - loss: 0.6717 - categorical_accuracy: 0.7594
# Epoch 00014: saving model to model_init_2022-11-1319_30_47.423460/model-00014-0.67167-0.75936-5.87230-0.50000.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.6717 - categorical_accuracy: 0.7594 - val_loss: 5.8723 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 15/40
# 11/11 [==============================] - ETA: 0s - loss: 0.5007 - categorical_accuracy: 0.8289
# Epoch 00015: saving model to model_init_2022-11-1319_30_47.423460/model-00015-0.50074-0.82888-16.84902-0.12500.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.5007 - categorical_accuracy: 0.8289 - val_loss: 16.8490 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 16/40
# 11/11 [==============================] - ETA: 0s - loss: 0.5647 - categorical_accuracy: 0.7861
# Epoch 00016: saving model to model_init_2022-11-1319_30_47.423460/model-00016-0.56471-0.78610-17.89188-0.37500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.5647 - categorical_accuracy: 0.7861 - val_loss: 17.8919 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 17/40
# 11/11 [==============================] - ETA: 0s - loss: 0.6163 - categorical_accuracy: 0.7701
# Epoch 00017: saving model to model_init_2022-11-1319_30_47.423460/model-00017-0.61629-0.77005-10.59499-0.12500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.6163 - categorical_accuracy: 0.7701 - val_loss: 10.5950 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 18/40
# 11/11 [==============================] - ETA: 0s - loss: 0.3632 - categorical_accuracy: 0.8556
# Epoch 00018: saving model to model_init_2022-11-1319_30_47.423460/model-00018-0.36319-0.85561-15.48939-0.25000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.3632 - categorical_accuracy: 0.8556 - val_loss: 15.4894 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 19/40
# 11/11 [==============================] - ETA: 0s - loss: 0.3094 - categorical_accuracy: 0.8556
# Epoch 00019: saving model to model_init_2022-11-1319_30_47.423460/model-00019-0.30943-0.85561-21.58236-0.00000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.3094 - categorical_accuracy: 0.8556 - val_loss: 21.5824 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 20/40
# 11/11 [==============================] - ETA: 0s - loss: 0.3850 - categorical_accuracy: 0.8235
# Epoch 00020: saving model to model_init_2022-11-1319_30_47.423460/model-00020-0.38495-0.82353-21.65244-0.12500.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.3850 - categorical_accuracy: 0.8235 - val_loss: 21.6524 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 21/40
# 11/11 [==============================] - ETA: 0s - loss: 0.4028 - categorical_accuracy: 0.8289
# Epoch 00021: saving model to model_init_2022-11-1319_30_47.423460/model-00021-0.40277-0.82888-14.56048-0.25000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.4028 - categorical_accuracy: 0.8289 - val_loss: 14.5605 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 22/40
# 11/11 [==============================] - ETA: 0s - loss: 0.2968 - categorical_accuracy: 0.8770
# Epoch 00022: saving model to model_init_2022-11-1319_30_47.423460/model-00022-0.29683-0.87701-16.43856-0.37500.h5
# 11/11 [==============================] - 24s 2s/step - loss: 0.2968 - categorical_accuracy: 0.8770 - val_loss: 16.4386 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 23/40
# 11/11 [==============================] - ETA: 0s - loss: 0.3405 - categorical_accuracy: 0.8663
# Epoch 00023: saving model to model_init_2022-11-1319_30_47.423460/model-00023-0.34055-0.86631-13.90598-0.12500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.3405 - categorical_accuracy: 0.8663 - val_loss: 13.9060 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 24/40
# 11/11 [==============================] - ETA: 0s - loss: 0.4260 - categorical_accuracy: 0.8449
# Epoch 00024: saving model to model_init_2022-11-1319_30_47.423460/model-00024-0.42599-0.84492-15.81523-0.25000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.4260 - categorical_accuracy: 0.8449 - val_loss: 15.8152 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 25/40
# 11/11 [==============================] - ETA: 0s - loss: 0.3844 - categorical_accuracy: 0.8663
# Epoch 00025: saving model to model_init_2022-11-1319_30_47.423460/model-00025-0.38438-0.86631-10.71288-0.12500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.3844 - categorical_accuracy: 0.8663 - val_loss: 10.7129 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 26/40
# 11/11 [==============================] - ETA: 0s - loss: 0.2003 - categorical_accuracy: 0.9251
# Epoch 00026: saving model to model_init_2022-11-1319_30_47.423460/model-00026-0.20034-0.92513-12.54683-0.25000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.2003 - categorical_accuracy: 0.9251 - val_loss: 12.5468 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 27/40
# 11/11 [==============================] - ETA: 0s - loss: 0.2134 - categorical_accuracy: 0.9251
# Epoch 00027: saving model to model_init_2022-11-1319_30_47.423460/model-00027-0.21344-0.92513-9.77353-0.25000.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.2134 - categorical_accuracy: 0.9251 - val_loss: 9.7735 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 28/40
# 11/11 [==============================] - ETA: 0s - loss: 0.5369 - categorical_accuracy: 0.8610
# Epoch 00028: saving model to model_init_2022-11-1319_30_47.423460/model-00028-0.53695-0.86096-21.36265-0.25000.h5
# 11/11 [==============================] - 24s 2s/step - loss: 0.5369 - categorical_accuracy: 0.8610 - val_loss: 21.3627 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 29/40
# 11/11 [==============================] - ETA: 0s - loss: 0.2085 - categorical_accuracy: 0.9144
# Epoch 00029: saving model to model_init_2022-11-1319_30_47.423460/model-00029-0.20851-0.91444-17.13029-0.12500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.2085 - categorical_accuracy: 0.9144 - val_loss: 17.1303 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 30/40
# 11/11 [==============================] - ETA: 0s - loss: 0.2483 - categorical_accuracy: 0.9037
# Epoch 00030: saving model to model_init_2022-11-1319_30_47.423460/model-00030-0.24829-0.90374-19.22153-0.12500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.2483 - categorical_accuracy: 0.9037 - val_loss: 19.2215 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 31/40
# 11/11 [==============================] - ETA: 0s - loss: 0.3141 - categorical_accuracy: 0.8877
# Epoch 00031: saving model to model_init_2022-11-1319_30_47.423460/model-00031-0.31406-0.88770-9.66144-0.37500.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.3141 - categorical_accuracy: 0.8877 - val_loss: 9.6614 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 32/40
# 11/11 [==============================] - ETA: 0s - loss: 0.2371 - categorical_accuracy: 0.9144
# Epoch 00032: saving model to model_init_2022-11-1319_30_47.423460/model-00032-0.23711-0.91444-4.45508-0.37500.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.2371 - categorical_accuracy: 0.9144 - val_loss: 4.4551 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 33/40
# 11/11 [==============================] - ETA: 0s - loss: 0.1847 - categorical_accuracy: 0.9465
# Epoch 00033: saving model to model_init_2022-11-1319_30_47.423460/model-00033-0.18466-0.94652-0.57028-0.75000.h5
# 11/11 [==============================] - 27s 3s/step - loss: 0.1847 - categorical_accuracy: 0.9465 - val_loss: 0.5703 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 34/40
# 11/11 [==============================] - ETA: 0s - loss: 0.1027 - categorical_accuracy: 0.9679
# Epoch 00034: saving model to model_init_2022-11-1319_30_47.423460/model-00034-0.10269-0.96791-5.96427-0.25000.h5
# 11/11 [==============================] - 24s 2s/step - loss: 0.1027 - categorical_accuracy: 0.9679 - val_loss: 5.9643 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 35/40
# 11/11 [==============================] - ETA: 0s - loss: 0.1605 - categorical_accuracy: 0.9465
# Epoch 00035: saving model to model_init_2022-11-1319_30_47.423460/model-00035-0.16053-0.94652-1.49441-0.62500.h5
# 11/11 [==============================] - 25s 3s/step - loss: 0.1605 - categorical_accuracy: 0.9465 - val_loss: 1.4944 - val_categorical_accuracy: 0.6250 - lr: 0.0010
# Epoch 36/40
# 11/11 [==============================] - ETA: 0s - loss: 0.1533 - categorical_accuracy: 0.9358
# Epoch 00036: saving model to model_init_2022-11-1319_30_47.423460/model-00036-0.15328-0.93583-8.35367-0.25000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.1533 - categorical_accuracy: 0.9358 - val_loss: 8.3537 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 37/40
# 11/11 [==============================] - ETA: 0s - loss: 0.2182 - categorical_accuracy: 0.9198
# Epoch 00037: saving model to model_init_2022-11-1319_30_47.423460/model-00037-0.21819-0.91979-8.98174-0.25000.h5
# 11/11 [==============================] - 25s 2s/step - loss: 0.2182 - categorical_accuracy: 0.9198 - val_loss: 8.9817 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 38/40
# 11/11 [==============================] - ETA: 0s - loss: 0.2183 - categorical_accuracy: 0.9251
# Epoch 00038: saving model to model_init_2022-11-1319_30_47.423460/model-00038-0.21829-0.92513-9.45224-0.12500.h5
# 11/11 [==============================] - 26s 3s/step - loss: 0.2183 - categorical_accuracy: 0.9251 - val_loss: 9.4522 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 39/40
# 11/11 [==============================] - ETA: 0s - loss: 0.1078 - categorical_accuracy: 0.9679
# Epoch 00039: saving model to model_init_2022-11-1319_30_47.423460/model-00039-0.10779-0.96791-5.88788-0.50000.h5
# 11/11 [==============================] - 24s 2s/step - loss: 0.1078 - categorical_accuracy: 0.9679 - val_loss: 5.8879 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 40/40
# 11/11 [==============================] - ETA: 0s - loss: 0.2270 - categorical_accuracy: 0.9519
# Epoch 00040: saving model to model_init_2022-11-1319_30_47.423460/model-00040-0.22698-0.95187-3.21215-0.75000.h5
# 11/11 [==============================] - 26s 2s/step - loss: 0.2270 - categorical_accuracy: 0.9519 - val_loss: 3.2121 - val_categorical_accuracy: 0.7500 - lr: 0.0010

# %%
plt.figure(figsize=(20,6))
ax1 = plt.subplot(121)
ax1 = plt.plot(history.history['loss'])
ax1 = plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')
ax2 = plt.subplot(122)
ax2 = plt.plot(history.history['categorical_accuracy'])
ax2 = plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower left')

# %%
rm -rf ~/.local/share/Trash/*
